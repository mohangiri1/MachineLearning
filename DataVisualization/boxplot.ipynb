# %% [markdown]
# <a href="https://colab.research.google.com/github/mohangiri1/MachineLearning/blob/main/DataVisualization/boxplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Box Plot for Visualization:

# %% [markdown]
# ### Import necessary packages:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import Data for visualization from scikit learn:

# %%
from sklearn.datasets import load_iris
iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# # Use pandas to plot three different kinds of box plots:

# %% [markdown]
# ### Single Plot:

# %%
iris_df['sepal length (cm)'].plot(kind='box')
plt.show()

# %% [markdown]
# ### Categorical Plot:

# %%
plt.figure(figsize=(30, 10))
iris_df.boxplot(column='sepal length (cm)', by='petal width (cm)')
plt.show()

# %% [markdown]
# ### Multiple Plots:

# %%
plt.figure(figsize=(20, 10))
iris_df.boxplot()
plt.show()

# %%
plt.figure(figsize=(20, 10))
iris_df.boxplot()
plt.semilogy()
plt.show()

# %% [markdown]
# # Boxplot using seaborn:

# %% [markdown]
# ### Single plot

# %%
sns.boxplot(x = 'sepal length (cm)', data = iris_df)
plt.show()

# %%
sns.boxplot(y = 'petal length (cm)', data = iris_df)
plt.show()

# %% [markdown]
# ### Categorical Plot:

# %%
sns.set(rc = {'figure.figsize': (20,10)})
sns.boxplot(y = 'sepal length (cm)', x = 'petal width (cm)', data = iris_df)
plt.show()

# %% [markdown]
# ### Multiple Plots:

# %%
sns.set(rc = {'figure.figsize': (20,20)})
sns.boxplot(data = iris_df)
plt.show()

# %% [markdown]
# # Boxplots Using Matplotlib:

# %% [markdown]
# ### Single Plot:

# %%
plt.figure(figsize=(10, 5))
plt.boxplot(iris_df['sepal length (cm)'])
plt.show()

# %% [markdown]
# ### Categorical Plot:

# %%
plt.figure(figsize=(10, 5))
plt.boxplot([iris_df['sepal length (cm)'], iris_df['petal width (cm)']], labels=['Sepal Length', 'Petal Width'])
plt.title('Box Plot of Sepal Length and Petal Width')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# ### Multiple Plots:

# %%
plt.figure(figsize=(10, 5))
plt.boxplot([iris_df['sepal length (cm)'], iris_df['petal width (cm)'], iris_df['petal length (cm)']], labels=['Sepal Length', 'Petal Width', 'Petal Length'])
plt.title('Box Plot of Sepal Length, Petal Width, and Petal Length')
plt.ylabel('Value')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.boxplot([iris_df['sepal length (cm)'], iris_df['petal width (cm)'], iris_df['petal length (cm)']], labels=['Sepal Length', 'Petal Width', 'Petal Length'])
plt.semilogy()
plt.title('Box Plot of Sepal Length, Petal Width, and Petal Length')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# # References:
#
#
# *   [How to Create a Boxplot in Python](https://www.turing.com/kb/how-to-create-a-boxplot-in-python)

# %% [markdown]
# author: [Mohan Giri](https://www.linkedin.com/in/mohan-giri-0595a914a/)
